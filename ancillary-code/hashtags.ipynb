# %%
library("twitteR")

api_key <- "7ICGxNJPdbosOA67rorrJ1i9W"
api_secret <- "CGLcEPnJ8ZeQquy18jUjMzQK5xlDhLcRu4shtCnoTthrmU99IM"
access_token <- "771783467029917697-Du28kI7XpoKSeFRHnUy1rK4ANM6IZ5T"
access_token_secret <- "yg6spi2gpaFgbuxP0bBlr1Z0rjl2cMX9HwyXTW4Gqig3v"

setup_twitter_oauth(api_key,api_secret,access_token,access_token_secret)
# Out:
# [1] "Using direct authentication"

# %%
hashtag="#soccer";

# %%
tweets <- searchTwitter(hashtag,n=2500)

# %%
df=twListToDF(tweets)

# %%
Sys.setlocale(locale="C")
# Out:
# [1] "LC_CTYPE=C;LC_NUMERIC=C;LC_TIME=C;LC_COLLATE=C;LC_MONETARY=C;LC_MESSAGES=en_US.UTF-8;LC_PAPER=en_US.UTF-8;LC_NAME=C;LC_ADDRESS=C;LC_TELEPHONE=C;LC_MEASUREMENT=en_US.UTF-8;LC_IDENTIFICATION=C"

# %%
df
# Out:
#        text
# 1      <U+9999><U+5DDD><U+771F><U+53F8><U+9078><U+624B><U+304C><U+5DFB><U+304D><U+8FBC><U+307E><U+308C><U+305F><U+3002><U+72EC><U+30C9><U+30EB><U+30C8><U+30E0><U+30F3><U+30C8><U+3067><U+7206><U+767A><U+3001><U+72AF><U+884C><U+58F0><U+660E><U+306E><U+3088><U+3046><U+306A><U+624B><U+7D19><U+898B><U+3064><U+304B><U+308B><U+FF5C>MBS <U+5168><U+56FD><U+306E><U+30CB><U+30E5><U+30FC><U+30B9> https://t.co/oZrgpOzVLO #news #germany #dortmnt #MBS #CBC #TBS #tbc #soccer #<U+30C9><U+30EB><U+30C8><U+30E0><U+30F3><U+30C8> #<U+30C9><U+30A4><U+30C4>
# 2      <U+5C0F><U+5CF6><U+5149><U+9855><U+3000>area de gol<U+30D6><U+30ED><U+30B0><U+66F4><U+65B0><U+3057><U+307E><U+3057><U+305F><U+3002><U+4E45><U+3057><U+3076><U+308A><U+306E><U+30B8><U+30E5><U+30CB><U+30A2><U+30B5><U+30C3><U+30AB><U+30FC><U+6307><U+5C0E> https://t.co/k2FMpJVduY #cozispo #soccer
# 3      #christchurch #nimes and #sexe #avcilartesetturluescort cebeciescort #soccer joliet https://t.co/xKdp3UlFOL
# ...

# %%
res <- regmatches(df$text,gregexpr("#[[:alnum:]]+",df$text))
res
# Out:
# [[1]]
# [1] "#football" "#jleague"  "#soccer"   "#jfa"
#
# [[2]]
# [1] "#Soccer"
#
# [[3]]
# [1] "#soccer"
#
# [[4]]
# [1] "#houstonaces" "#weareback"   "#soccer"
#
# [[5]]
# [1] "#Soccer"
#
# [[6]]
# [1] "#soccer"   "#uefa"     "#thursday"
#
# [[7]]
# [1] "#Soccer"
#
# [[8]]
# [1] "#RepostBy"    "#simplemente" "#azul"        "#cse"         "#emelecista"
# [6] "#soccer"      "#boquera"
#
# [[9]]
# [1] "#animal" "#bdsm"   "#cars"   "#beauty" "#soccer"
#
# [[10]]
# [1] "#houstonaces" "#weareback"   "#soccer"
#
# [[11]]
# [1] "#soccer" "#foot"
#
# [[12]]
# [1] "#soccer"
#
# [[13]]
# [1] "#Soccer"
#
# [[14]]
# [1] "#news"   "#calcio" "#soccer"
#
# [[15]]
# [1] "#soccer" "#ESPN"
#
# [[16]]
# [1] "#soccer" "#rowing"
#
# [[17]]
# [1] "#Soccer"        "#SportsBetting" "#England"       "#Championship"
#
# [[18]]
# [1] "#TBT"    "#soccer"
#
# [[19]]
# [1] "#iproskillsacademy" "#soccer"            "#chicagosoccercamp"
# [4] "#soccerinchicago"
#
# [[20]]
# [1] "#soccer"
#
# [[21]]
# ...

# %%
cat(sapply(res,toString), file="test1.txt", sep="\n")
